# %%
import os
import math
import random

# %%
import json
import numpy as np
import mxnet as mx
import cv2

import matplotlib.pyplot as plt

# %%
def Conv(data, num_filter=1, kernel=(1, 1), stride=(1, 1), pad=(0, 0), num_group=1, name=None, suffix='', cudnn_off=False):
    conv = mx.sym.Convolution(data=data, num_filter=num_filter, kernel=kernel, num_group=num_group, stride=stride, pad=pad, no_bias=True, name='%s' % name, cudnn_off=cudnn_off)
    bn = mx.sym.BatchNorm(data=conv, name='%s_bn' % name, fix_gamma=False, use_global_stats=False, eps=0.0001, attr={'lr_mult': '1.0'})
    act = mx.sym.Activation(data=bn, act_type='relu', name='%s_relu' % name )
    return act

# %%
def mobile_net(w_factor=1.):
    data = mx.symbol.Variable(name='data')
    #label = mx.symbol.Variable(name="label")
    
    w1 = int(w_factor * 32) # 32
    w2 = w1 * 2 # 64
    w3 = w2 * 2 # 128
    w4 = w3 * 2 # 256
    w5 = w4 * 2 # 512
    w6 = w5 * 2 # 1024
    
    conv1 = Conv(data, num_filter=w1, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name="conv1") # 224/112

    conv2_1_dw = Conv(conv1, num_group=w1, num_filter=w1, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv2_1_dw", cudnn_off=True) # 112/112
    conv2_1_sep = Conv(conv2_1_dw, num_filter=w2, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv2_1_sep") # 112/112
    conv2_2_dw = Conv(conv2_1_sep, num_group=w2, num_filter=w2, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name="conv2_2_dw", cudnn_off=True) # 112/56
    conv2_2_sep = Conv(conv2_2_dw, num_filter=w3, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv2_2_sep") # 56/56

    conv3_1_dw = Conv(conv2_2_sep, num_group=w3, num_filter=w3, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv3_1_dw", cudnn_off=True) # 56/56
    conv3_1_sep = Conv(conv3_1_dw, num_filter=w3, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv3_1_sep") # 56/56
    conv3_2_dw = Conv(conv3_1_sep, num_group=w3, num_filter=w3, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name="conv3_2_dw", cudnn_off=True) # 56/28
    conv3_2_sep = Conv(conv3_2_dw, num_filter=w4, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv3_2_sep") # 28/28

    conv4_1_dw = Conv(conv3_2_sep, num_group=w4, num_filter=w4, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv4_1_dw", cudnn_off=True) # 28/28
    conv4_1_sep = Conv(conv4_1_dw, num_filter=w4, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv4_1_sep") # 28/28
    conv4_2_dw = Conv(conv4_1_sep, num_group=w4, num_filter=w4, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name="conv4_2_dw", cudnn_off=True) # 28/14
    conv4_2_sep = Conv(conv4_2_dw, num_filter=w5, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv4_2_sep") # 14/14

    conv5_1_dw = Conv(conv4_2_sep, num_group=w5, num_filter=w5, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv5_1_dw", cudnn_off=True) # 14/14
    conv5_1_sep = Conv(conv5_1_dw, num_filter=w5, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv5_1_sep") # 14/14
    conv5_2_dw = Conv(conv5_1_sep, num_group=w5, num_filter=w5, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv5_2_dw", cudnn_off=True) # 14/14
    conv5_2_sep = Conv(conv5_2_dw, num_filter=w5, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv5_2_sep") # 14/14
    conv5_3_dw = Conv(conv5_2_sep, num_group=w5, num_filter=w5, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv5_3_dw", cudnn_off=True) # 14/14
    conv5_3_sep = Conv(conv5_3_dw, num_filter=w5, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv5_3_sep") # 14/14
    conv5_4_dw = Conv(conv5_3_sep, num_group=w5, num_filter=w5, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv5_4_dw", cudnn_off=True) # 14/14
    conv5_4_sep = Conv(conv5_4_dw, num_filter=w5, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv5_4_sep") # 14/14
    conv5_5_dw = Conv(conv5_4_sep, num_group=w5, num_filter=w5, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv5_5_dw", cudnn_off=True) # 14/14
    conv5_5_sep = Conv(conv5_5_dw, num_filter=w5, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv5_5_sep") # 14/14
    conv5_6_dw = Conv(conv5_5_sep, num_group=w5, num_filter=w5, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name="conv5_6_dw", cudnn_off=True) # 14/7
    conv5_6_sep = Conv(conv5_6_dw, num_filter=w6, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv5_6_sep") # 7/7

    conv6_dw = Conv(conv5_6_sep, num_group=w6, num_filter=w6, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name="conv6_dw", cudnn_off=True) # 7/7
    conv6_sep = Conv(conv6_dw, num_filter=w6, kernel=(1, 1), pad=(0, 0), stride=(1, 1), name="conv6_sep") # 7/7

    pool6 = mx.symbol.Pooling(name='pool6', data=conv6_sep , pooling_convention='full', global_pool=True, kernel=(1,1), pool_type='avg')

    fc7 = mx.symbol.Convolution(name='fc7', data=pool6 , num_filter=2, pad=(0, 0), kernel=(1,1), stride=(1,1), no_bias=False)
    flatten = mx.symbol.Flatten(data=fc7, name='flatten')
    softmax = mx.symbol.SoftmaxOutput(data=flatten, name='softmax')
    return softmax

# %%
data_shape = 128
mean_val = np.array([[[123.68]],[[116.78]],[[103.94]]])
std_scale = 0.017

# %%
def get_dg_db():
    dat_path = '/mnt/6B133E147DED759E/Archive2017.8.16_res'

    with open(dat_path + '/data.json') as f:
        infos = json.load(f)

    #imgs = [cv2.cvtColor(cv2.imread(dat_path+'/'+i['filename']),cv2.COLOR_BGR2RGB) for i in infos]
    #imgs = [cv2.cvtColor(cv2.imread(dat_path+'/'+i['filename']),cv2.COLOR_BGR2RGB) for i in infos]
    imgs = []
    for i in infos:
        img = cv2.imread(dat_path+'/'+i['filename'])
        #print(i['filename'])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         x0 = i['xmin']
#         x1 = i['xmax']
#         y0 = i['ymin']
#         y1 = i['ymax']
#         cv2.rectangle(img, (x0,y0),(x1,y1),(0,0,255),3)
#         plt.imshow(img)
#         plt.show()
        imgs.append(img)
    
    return infos, imgs

# %%
class DGIter(mx.io.DataIter):
    def __init__(self, db, batch_size=1, image_shape=128, data_name='data', label_name='softmax_label'):
        super(DGIter, self).__init__(batch_size)
        
        self.db_json = db[0]
        #self.db_dict = db[0]
        #self.imgfiles = db[2]
        self.imgs = db[1]
        #self.masks = db[4]
        self.image_shape = image_shape
        
        self.num_data = len(self.imgs)
        self.idx = np.arange(0, self.num_data)
        np.random.shuffle(self.idx)
        
        assert self.num_data >= batch_size, "batch_size needs to be smaller than data size."
        
        self.cursor = -batch_size
        self.batch_size = batch_size
    
    # TODO: 
    @property
    def provide_data(self):
        """The name and shape of data provided by this iterator."""
        return [
            mx.io.DataDesc('data', (self.batch_size, 3, self.image_shape, self.image_shape))
        ]

    # TODO: 
    @property
    def provide_label(self):
        """The name and shape of label provided by this iterator."""
        return [
             mx.io.DataDesc('y', (self.batch_size,)) #, mx.io.DataDesc('kps', (self.batch_size, 10))
        ]
    
    def hard_reset(self):
        np.random.shuffle(self.idx)
        """Ignore roll over data and set to start."""
        self.cursor = -self.batch_size
        
    def reset(self):
        self.cursor = -self.batch_size
        
    def iter_next(self):
        self.cursor += self.batch_size
        return self.cursor < self.num_data

    def sample_batch(self, sample_list):
        imgs = np.empty(shape=(self.batch_size, 3, self.image_shape, self.image_shape), dtype=np.float32)
        y = np.empty(shape=(self.batch_size,), dtype=np.float32)

        for k,i in enumerate(sample_list):
            img = self.imgs[i]
            info = self.db_json[i]
            
            x0 = info['xmin']
            x1 = info['xmax']
            y0 = info['ymin']
            y1 = info['ymax']
            
            dg_type = info['type']

            dst_w = self.image_shape
            dst_h = self.image_shape
            obj_w = x1 - x0
            obj_h = y1 - y0
            xc = (x0 + x1) / 2.
            yc = (y0 + y1) / 2.
            #scale = dst_w / max(obj_w, obj_h)
            scale_w = dst_w / float(obj_w)
            scale_h = dst_h / float(obj_h)

            sj = random.uniform(0.9, 1.2)
            scale_jitter_w = sj * random.choice([-1,1])
            scale_jitter_h = sj * random.choice([-1,1])
            
            scale_w *= scale_jitter_w
            scale_h *= scale_jitter_h
            
            dst_w_jitter = random.uniform(-20,20)
            dst_h_jitter = random.uniform(-15,15)
            theta = random.uniform(-np.pi/40, np.pi/40)

            T0 = np.array([[1,0,-xc],[0,1,-yc],[0,0,1]])
            S = np.array([[scale_w,0,0],[0, scale_h,0],[0,0,1]])
            R = np.array([[np.cos(theta), np.sin(theta), 0], [-np.sin(theta), np.cos(theta), 0],[0,0,1]])
            T1 = np.array([[1,0,dst_w/2. +dst_w_jitter],[0,1,dst_h/2. +dst_h_jitter],[0,0,1]])
            M = np.dot(S, T0)
            M = np.dot(R, M)
            M = np.dot(T1, M)
            M_warp = M[0:2,:]

            dst_img = cv2.warpAffine(img, M_warp, dsize=(int(dst_w), int(dst_h)))
            dst_img = np.transpose(dst_img,(2,0,1))
            dst_img = std_scale * (dst_img.astype(np.float32) - mean_val)
            
            imgs[k][:] = dst_img
            y[k] = dg_type
        return imgs, y
    
    def getdata(self):
        assert(self.cursor < self.num_data), "DataIter needs reset."
        if self.cursor + self.batch_size <= self.num_data:
            l = list(range(self.cursor, self.cursor + self.batch_size))
        else:
            pad = self.batch_size - self.num_data + self.cursor
            l = list(range(self.cursor, self.num_data)) + list(range(0,pad))
        
        
        
        sample_list = [self.idx[i] for i in l]
        images, y = self.sample_batch(sample_list)
        images = mx.nd.array(images)
        y = mx.nd.array(y)
        #kps = mx.nd.array(kps)
        return images, y

    #def getlabel(self):
    #    return self.rand_trans(self.label, True)
    
    # TODO: 
    def next(self):
        if self.iter_next():
            images, y = self.getdata()
            return mx.io.DataBatch(data=[images], label=[y], pad=self.getpad(), index=None)
        else:
            raise StopIteration
    
    def getpad(self):
        if self.cursor + self.batch_size > self.num_data:
            return self.cursor + self.batch_size - self.num_data
        else:
            return 0

# %%
db = get_dg_db()

# %%
ylb_iter = DGIter(db, 256, image_shape=data_shape)

# %%
# import matplotlib.pyplot as plt
# for i in range(20):
#     ylb_iter.reset()
#     for batch in ylb_iter:
#         plt.imshow(batch.data[0][0,1].asnumpy())
#         plt.show()
#         print(batch.label[0][0])

# %%
# mx.viz.plot_network(softmax,shape={'data':(8,1,224,224)}, node_attrs={'shape':'oval','fixedsize':'fasl==false'}).view()

# %%
pretrain=0

# %%
if pretrain:
    sym = mobile_net()
    layers = sym.get_internals()
    y = mx.sym.Variable('y')
    pool6 = layers['pool6_output']
    fc7 = mx.symbol.Convolution(name='fc7', data=pool6 , num_filter=2, pad=(0, 0), kernel=(1,1), stride=(1,1), no_bias=False)
    flatten = mx.symbol.Flatten(data=fc7, name='flatten')
    softmax = mx.sym.SoftmaxOutput(data=flatten, label=y, name = 'softmax')

    #mx.viz.plot_network(softmax,shape={'data':(8,3,data_shape,data_shape)}, node_attrs={'shape':'oval','fixedsize':'fasl==false'}).view()
    params = mx.nd.load('mobilenet-0000.params')
    graph=json.loads(sym.tojson())

    arg_params = {}
    aux_params = {}
    for i, n in enumerate(graph['nodes']):
        if n['op'] == 'Convolution' or n['op'] == 'FullyConnected':
            arg_params[n['name']+'_weight'] = params['arg:'+n['name']+'_weight']
            if n['attr']['no_bias'] == 'False':
                arg_params[n['name']+'_bias'] = params['arg:'+n['name']+'_bias']
        elif n['op'] == 'BatchNorm':
            arg_params[n['name']+'_gamma'] = params['arg:'+n['name']+'_gamma']
            arg_params[n['name']+'_beta'] = params['arg:'+n['name']+'_beta']
            aux_params[n['name']+'_moving_mean'] = params['aux:'+n['name']+'_moving_mean']
            aux_params[n['name']+'_moving_var'] = params['aux:'+n['name']+'_moving_var']
        else:
            pass
    
    arg_shapes, _, aux_shapes = softmax.infer_shape(data=(1,3,data_shape,data_shape))
    arg_names = softmax.list_arguments()
    aux_names = softmax.list_auxiliary_states()
    arg_shape_dic = dict(zip(arg_names, arg_shapes))
    aux_shape_dic = dict(zip(aux_names, aux_shapes))

    arg_params['fc7_weight'] = mx.nd.random_normal(shape=(arg_shape_dic['fc7_weight'])) *.01
    arg_params['fc7_bias'] = mx.nd.zeros(shape=(arg_shape_dic['fc7_bias'])) *.01
else:   
    sym = mobile_net(0.25)
    layers = sym.get_internals()
    y = mx.sym.Variable('y')
    pool6 = layers['pool6_output']
    fc7 = mx.symbol.Convolution(name='fc7', data=pool6 , num_filter=2, pad=(0, 0), kernel=(1,1), stride=(1,1), no_bias=False)
    flatten = mx.symbol.Flatten(data=fc7, name='flatten')
    softmax = mx.sym.SoftmaxOutput(data=flatten, label=y, name = 'softmax')

# %%
ctx = [mx.gpu(0),mx.gpu(1),mx.gpu(2),mx.gpu(3)]
mod = mx.mod.Module(softmax, data_names=['data'], label_names=['y'], context=ctx)

# %%
#mx.viz.plot_network(softmax,shape={'data':(8,3,data_shape,data_shape)}, node_attrs={'shape':'oval','fixedsize':'fasl==false'}).view()

# %%
mod.bind(for_training=True, data_shapes=ylb_iter.provide_data, label_shapes=ylb_iter.provide_label)
if pretrain:
    print("PRETRAIN")
    mod.set_params(arg_params=arg_params, aux_params=aux_params, allow_extra=True)
else:
    print("SCRATCH")
    mod.init_params(initializer=mx.init.Xavier(magnitude=2.))
# Out:
# SCRATCH

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %%
batches = ylb_iter.num_data / float(ylb_iter.batch_size)
lr_sch = mx.lr_scheduler.MultiFactorScheduler([int(32 * batches), int(64 * batches)], 0.5)
#optimizer =mx.optimizer.SGD(momentum = 0.9, learning_rate=0.0001, momentum=0.9, lr_scheduler=lr_sch, rescale_grad=1.0/nd_iter.batch_size)
mod.init_optimizer(optimizer='RMSProp', optimizer_params={'learning_rate':0.001, 'lr_scheduler': lr_sch, 'wd': 0.00005,
                                                         'rescale_grad': 1.0 / len(ctx) if len(ctx) > 0 else 1.0 })
#mod.init_optimizer(optimizer='sgd', optimizer_params={'learning_rate':0.001, 'momentum': 0.9, 'lr_scheduler': lr_sch})
# Out:
# WARNING:root:optimizer already initialized, ignoring...

# %%
epoch_end_callback = mx.callback.do_checkpoint("dg")
ylb_iter.reset()
mod.fit(ylb_iter, num_epoch=100,eval_metric= 'acc', epoch_end_callback = epoch_end_callback)
#metric = mx.metric.create('acc')
# Out:
# WARNING:root:Already bound, ignoring bind()
# /home/dingkou/dev/incubator-mxnet/python/mxnet/module/base_module.py:464: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Train-accuracy=0.839323
# INFO:root:Epoch[0] Time cost=7.142
# INFO:root:Saved checkpoint to "dg-0001.params"
# INFO:root:Epoch[1] Train-accuracy=0.894618
# INFO:root:Epoch[1] Time cost=6.617
# INFO:root:Saved checkpoint to "dg-0002.params"
# INFO:root:Epoch[2] Train-accuracy=0.914497
# INFO:root:Epoch[2] Time cost=6.505
# INFO:root:Saved checkpoint to "dg-0003.params"
# INFO:root:Epoch[3] Train-accuracy=0.922309
# INFO:root:Epoch[3] Time cost=6.497
# INFO:root:Saved checkpoint to "dg-0004.params"
# INFO:root:Epoch[4] Train-accuracy=0.941146
# INFO:root:Epoch[4] Time cost=6.645
# INFO:root:Saved checkpoint to "dg-0005.params"
# INFO:root:Epoch[5] Train-accuracy=0.947309
# INFO:root:Epoch[5] Time cost=6.548
# INFO:root:Saved checkpoint to "dg-0006.params"
# INFO:root:Epoch[6] Train-accuracy=0.957986
# INFO:root:Epoch[6] Time cost=6.396
# INFO:root:Saved checkpoint to "dg-0007.params"
# INFO:root:Epoch[7] Train-accuracy=0.965191
# INFO:root:Epoch[7] Time cost=6.427
# INFO:root:Saved checkpoint to "dg-0008.params"
# INFO:root:Epoch[8] Train-accuracy=0.971615
# INFO:root:Epoch[8] Time cost=6.672
# INFO:root:Saved checkpoint to "dg-0009.params"
# INFO:root:Epoch[9] Train-accuracy=0.975521
# INFO:root:Epoch[9] Time cost=6.593
# INFO:root:Saved checkpoint to "dg-0010.params"
# INFO:root:Epoch[10] Train-accuracy=0.977691
# INFO:root:Epoch[10] Time cost=6.508
# INFO:root:Saved checkpoint to "dg-0011.params"
# INFO:root:Epoch[11] Train-accuracy=0.979167
# INFO:root:Epoch[11] Time cost=6.659
# INFO:root:Saved checkpoint to "dg-0012.params"
# INFO:root:Epoch[12] Train-accuracy=0.982378
# INFO:root:Epoch[12] Time cost=6.688
# INFO:root:Saved checkpoint to "dg-0013.params"
# INFO:root:Epoch[13] Train-accuracy=0.982292
# INFO:root:Epoch[13] Time cost=6.871
# INFO:root:Saved checkpoint to "dg-0014.params"
# INFO:root:Epoch[14] Train-accuracy=0.984028
# INFO:root:Epoch[14] Time cost=6.445
# INFO:root:Saved checkpoint to "dg-0015.params"
# INFO:root:Epoch[15] Train-accuracy=0.983507
# INFO:root:Epoch[15] Time cost=6.520
# INFO:root:Saved checkpoint to "dg-0016.params"
# INFO:root:Epoch[16] Train-accuracy=0.985764
# INFO:root:Epoch[16] Time cost=6.554
# INFO:root:Saved checkpoint to "dg-0017.params"
# INFO:root:Epoch[17] Train-accuracy=0.985069
# INFO:root:Epoch[17] Time cost=6.653
# INFO:root:Saved checkpoint to "dg-0018.params"
# INFO:root:Epoch[18] Train-accuracy=0.986545
# INFO:root:Epoch[18] Time cost=6.416
# INFO:root:Saved checkpoint to "dg-0019.params"
# INFO:root:Epoch[19] Train-accuracy=0.986806
# INFO:root:Epoch[19] Time cost=6.462
# INFO:root:Saved checkpoint to "dg-0020.params"
# INFO:root:Epoch[20] Train-accuracy=0.986979
# INFO:root:Epoch[20] Time cost=6.506
# INFO:root:Saved checkpoint to "dg-0021.params"
# INFO:root:Epoch[21] Train-accuracy=0.985764
# INFO:root:Epoch[21] Time cost=6.744
# INFO:root:Saved checkpoint to "dg-0022.params"
# INFO:root:Epoch[22] Train-accuracy=0.987066
# INFO:root:Epoch[22] Time cost=6.694
# INFO:root:Saved checkpoint to "dg-0023.params"
# INFO:root:Epoch[23] Train-accuracy=0.988368
# INFO:root:Epoch[23] Time cost=6.561
# INFO:root:Saved checkpoint to "dg-0024.params"
# INFO:root:Epoch[24] Train-accuracy=0.989583
# INFO:root:Epoch[24] Time cost=6.609
# INFO:root:Saved checkpoint to "dg-0025.params"
# INFO:root:Epoch[25] Train-accuracy=0.988715
# INFO:root:Epoch[25] Time cost=6.724
# INFO:root:Saved checkpoint to "dg-0026.params"
# INFO:root:Epoch[26] Train-accuracy=0.989410
# INFO:root:Epoch[26] Time cost=6.553
# INFO:root:Saved checkpoint to "dg-0027.params"
# INFO:root:Epoch[27] Train-accuracy=0.989931
# INFO:root:Epoch[27] Time cost=6.477
# INFO:root:Saved checkpoint to "dg-0028.params"
# INFO:root:Epoch[28] Train-accuracy=0.990712
# INFO:root:Epoch[28] Time cost=6.573
# INFO:root:Saved checkpoint to "dg-0029.params"
# INFO:root:Epoch[29] Train-accuracy=0.990712
# INFO:root:Epoch[29] Time cost=6.633
# INFO:root:Saved checkpoint to "dg-0030.params"
# INFO:root:Epoch[30] Train-accuracy=0.991319
# INFO:root:Epoch[30] Time cost=6.461
# INFO:root:Saved checkpoint to "dg-0031.params"
# INFO:root:Update[1416]: Change learning rate to 5.00000e-04
# INFO:root:Epoch[31] Train-accuracy=0.992101
# INFO:root:Epoch[31] Time cost=6.618
# INFO:root:Saved checkpoint to "dg-0032.params"
# INFO:root:Epoch[32] Train-accuracy=0.993229
# INFO:root:Epoch[32] Time cost=6.374
# INFO:root:Saved checkpoint to "dg-0033.params"
# INFO:root:Epoch[33] Train-accuracy=0.993229
# INFO:root:Epoch[33] Time cost=6.708
# INFO:root:Saved checkpoint to "dg-0034.params"
# INFO:root:Epoch[34] Train-accuracy=0.993403
# INFO:root:Epoch[34] Time cost=6.526
# INFO:root:Saved checkpoint to "dg-0035.params"
# INFO:root:Epoch[35] Train-accuracy=0.993750
# INFO:root:Epoch[35] Time cost=6.742
# INFO:root:Saved checkpoint to "dg-0036.params"
# INFO:root:Epoch[36] Train-accuracy=0.994184
# INFO:root:Epoch[36] Time cost=6.693
# INFO:root:Saved checkpoint to "dg-0037.params"
# INFO:root:Epoch[37] Train-accuracy=0.994444
# INFO:root:Epoch[37] Time cost=6.638
# INFO:root:Saved checkpoint to "dg-0038.params"
# INFO:root:Epoch[38] Train-accuracy=0.994618
# INFO:root:Epoch[38] Time cost=6.771
# INFO:root:Saved checkpoint to "dg-0039.params"
# INFO:root:Epoch[39] Train-accuracy=0.994878
# INFO:root:Epoch[39] Time cost=6.488
# INFO:root:Saved checkpoint to "dg-0040.params"
# INFO:root:Epoch[40] Train-accuracy=0.994792
# INFO:root:Epoch[40] Time cost=6.523
# INFO:root:Saved checkpoint to "dg-0041.params"
# INFO:root:Epoch[41] Train-accuracy=0.994010
# INFO:root:Epoch[41] Time cost=6.591
# INFO:root:Saved checkpoint to "dg-0042.params"
# INFO:root:Epoch[42] Train-accuracy=0.994965
# INFO:root:Epoch[42] Time cost=6.644
# INFO:root:Saved checkpoint to "dg-0043.params"
# INFO:root:Epoch[43] Train-accuracy=0.994965
# INFO:root:Epoch[43] Time cost=6.505
# INFO:root:Saved checkpoint to "dg-0044.params"
# INFO:root:Epoch[44] Train-accuracy=0.994618
# INFO:root:Epoch[44] Time cost=6.643
# INFO:root:Saved checkpoint to "dg-0045.params"
# INFO:root:Epoch[45] Train-accuracy=0.994878
# INFO:root:Epoch[45] Time cost=6.443
# INFO:root:Saved checkpoint to "dg-0046.params"
# INFO:root:Epoch[46] Train-accuracy=0.995573
# INFO:root:Epoch[46] Time cost=6.261
# INFO:root:Saved checkpoint to "dg-0047.params"
# INFO:root:Epoch[47] Train-accuracy=0.996267
# INFO:root:Epoch[47] Time cost=6.540
# INFO:root:Saved checkpoint to "dg-0048.params"
# INFO:root:Epoch[48] Train-accuracy=0.995833
# INFO:root:Epoch[48] Time cost=6.443
# INFO:root:Saved checkpoint to "dg-0049.params"
# INFO:root:Epoch[49] Train-accuracy=0.996267
# INFO:root:Epoch[49] Time cost=6.743
# INFO:root:Saved checkpoint to "dg-0050.params"
# INFO:root:Epoch[50] Train-accuracy=0.996615
# INFO:root:Epoch[50] Time cost=6.759
# INFO:root:Saved checkpoint to "dg-0051.params"
# INFO:root:Epoch[51] Train-accuracy=0.996267
# INFO:root:Epoch[51] Time cost=6.456
# INFO:root:Saved checkpoint to "dg-0052.params"
# INFO:root:Epoch[52] Train-accuracy=0.996441
# INFO:root:Epoch[52] Time cost=6.445
# INFO:root:Saved checkpoint to "dg-0053.params"
# INFO:root:Epoch[53] Train-accuracy=0.996094
# INFO:root:Epoch[53] Time cost=6.544
# INFO:root:Saved checkpoint to "dg-0054.params"
# INFO:root:Epoch[54] Train-accuracy=0.996528
# INFO:root:Epoch[54] Time cost=6.479
# INFO:root:Saved checkpoint to "dg-0055.params"
# INFO:root:Epoch[55] Train-accuracy=0.994792
# INFO:root:Epoch[55] Time cost=6.393
# INFO:root:Saved checkpoint to "dg-0056.params"
# INFO:root:Epoch[56] Train-accuracy=0.995747
# INFO:root:Epoch[56] Time cost=6.388
# INFO:root:Saved checkpoint to "dg-0057.params"
# INFO:root:Epoch[57] Train-accuracy=0.995313
# INFO:root:Epoch[57] Time cost=6.435
# INFO:root:Saved checkpoint to "dg-0058.params"
# INFO:root:Epoch[58] Train-accuracy=0.995226
# INFO:root:Epoch[58] Time cost=6.424
# INFO:root:Saved checkpoint to "dg-0059.params"
# INFO:root:Epoch[59] Train-accuracy=0.995920
# INFO:root:Epoch[59] Time cost=6.443
# INFO:root:Saved checkpoint to "dg-0060.params"
# INFO:root:Epoch[60] Train-accuracy=0.996007
# INFO:root:Epoch[60] Time cost=6.388
# INFO:root:Saved checkpoint to "dg-0061.params"
# INFO:root:Epoch[61] Train-accuracy=0.996528
# INFO:root:Epoch[61] Time cost=6.415
# INFO:root:Saved checkpoint to "dg-0062.params"
# INFO:root:Update[2832]: Change learning rate to 2.50000e-04
# INFO:root:Epoch[62] Train-accuracy=0.996701
# INFO:root:Epoch[62] Time cost=6.500
# INFO:root:Saved checkpoint to "dg-0063.params"
# INFO:root:Epoch[63] Train-accuracy=0.997830
# INFO:root:Epoch[63] Time cost=6.558
# INFO:root:Saved checkpoint to "dg-0064.params"
# INFO:root:Epoch[64] Train-accuracy=0.996875
# INFO:root:Epoch[64] Time cost=6.349
# INFO:root:Saved checkpoint to "dg-0065.params"
# INFO:root:Epoch[65] Train-accuracy=0.997222
# INFO:root:Epoch[65] Time cost=6.439
# INFO:root:Saved checkpoint to "dg-0066.params"
# INFO:root:Epoch[66] Train-accuracy=0.997049
# INFO:root:Epoch[66] Time cost=6.342
# INFO:root:Saved checkpoint to "dg-0067.params"
# INFO:root:Epoch[67] Train-accuracy=0.997569
# INFO:root:Epoch[67] Time cost=6.466
# INFO:root:Saved checkpoint to "dg-0068.params"
# INFO:root:Epoch[68] Train-accuracy=0.997135
# INFO:root:Epoch[68] Time cost=6.528
# INFO:root:Saved checkpoint to "dg-0069.params"
# INFO:root:Epoch[69] Train-accuracy=0.997483
# INFO:root:Epoch[69] Time cost=6.420
# INFO:root:Saved checkpoint to "dg-0070.params"
# INFO:root:Epoch[70] Train-accuracy=0.997222
# INFO:root:Epoch[70] Time cost=6.507
# INFO:root:Saved checkpoint to "dg-0071.params"
# INFO:root:Epoch[71] Train-accuracy=0.996962
# INFO:root:Epoch[71] Time cost=6.338
# INFO:root:Saved checkpoint to "dg-0072.params"
# INFO:root:Epoch[72] Train-accuracy=0.997917
# INFO:root:Epoch[72] Time cost=6.434
# INFO:root:Saved checkpoint to "dg-0073.params"
# INFO:root:Epoch[73] Train-accuracy=0.997135
# INFO:root:Epoch[73] Time cost=6.481
# INFO:root:Saved checkpoint to "dg-0074.params"
# INFO:root:Epoch[74] Train-accuracy=0.997049
# INFO:root:Epoch[74] Time cost=6.454
# INFO:root:Saved checkpoint to "dg-0075.params"
# INFO:root:Epoch[75] Train-accuracy=0.997830
# INFO:root:Epoch[75] Time cost=6.816
# INFO:root:Saved checkpoint to "dg-0076.params"
# INFO:root:Epoch[76] Train-accuracy=0.997309
# INFO:root:Epoch[76] Time cost=6.372
# INFO:root:Saved checkpoint to "dg-0077.params"
# INFO:root:Epoch[77] Train-accuracy=0.997743
# INFO:root:Epoch[77] Time cost=6.815
# INFO:root:Saved checkpoint to "dg-0078.params"
# INFO:root:Epoch[78] Train-accuracy=0.997656
# INFO:root:Epoch[78] Time cost=6.328
# INFO:root:Saved checkpoint to "dg-0079.params"
# INFO:root:Epoch[79] Train-accuracy=0.998090
# INFO:root:Epoch[79] Time cost=6.354
# INFO:root:Saved checkpoint to "dg-0080.params"
# INFO:root:Epoch[80] Train-accuracy=0.998003
# INFO:root:Epoch[80] Time cost=6.506
# INFO:root:Saved checkpoint to "dg-0081.params"
# INFO:root:Epoch[81] Train-accuracy=0.997656
# INFO:root:Epoch[81] Time cost=6.560
# INFO:root:Saved checkpoint to "dg-0082.params"
# INFO:root:Epoch[82] Train-accuracy=0.997135
# INFO:root:Epoch[82] Time cost=6.339
# INFO:root:Saved checkpoint to "dg-0083.params"
# INFO:root:Epoch[83] Train-accuracy=0.997917
# INFO:root:Epoch[83] Time cost=6.563
# INFO:root:Saved checkpoint to "dg-0084.params"
# INFO:root:Epoch[84] Train-accuracy=0.997309
# INFO:root:Epoch[84] Time cost=6.603
# INFO:root:Saved checkpoint to "dg-0085.params"
# INFO:root:Epoch[85] Train-accuracy=0.998611
# INFO:root:Epoch[85] Time cost=6.595
# INFO:root:Saved checkpoint to "dg-0086.params"
# INFO:root:Epoch[86] Train-accuracy=0.997743
# INFO:root:Epoch[86] Time cost=6.414
# INFO:root:Saved checkpoint to "dg-0087.params"
# INFO:root:Epoch[87] Train-accuracy=0.998177
# INFO:root:Epoch[87] Time cost=6.340
# INFO:root:Saved checkpoint to "dg-0088.params"
# INFO:root:Epoch[88] Train-accuracy=0.997656
# INFO:root:Epoch[88] Time cost=6.402
# INFO:root:Saved checkpoint to "dg-0089.params"
# INFO:root:Epoch[89] Train-accuracy=0.997917
# INFO:root:Epoch[89] Time cost=6.409
# INFO:root:Saved checkpoint to "dg-0090.params"
# INFO:root:Epoch[90] Train-accuracy=0.997656
# INFO:root:Epoch[90] Time cost=6.606
# INFO:root:Saved checkpoint to "dg-0091.params"
# INFO:root:Epoch[91] Train-accuracy=0.997743
# INFO:root:Epoch[91] Time cost=6.470
# INFO:root:Saved checkpoint to "dg-0092.params"
# INFO:root:Epoch[92] Train-accuracy=0.997483
# INFO:root:Epoch[92] Time cost=6.680
# INFO:root:Saved checkpoint to "dg-0093.params"
# INFO:root:Epoch[93] Train-accuracy=0.998090
# INFO:root:Epoch[93] Time cost=6.316
# INFO:root:Saved checkpoint to "dg-0094.params"
# INFO:root:Epoch[94] Train-accuracy=0.998090
# INFO:root:Epoch[94] Time cost=6.582
# INFO:root:Saved checkpoint to "dg-0095.params"
# INFO:root:Epoch[95] Train-accuracy=0.998177
# INFO:root:Epoch[95] Time cost=6.774
# INFO:root:Saved checkpoint to "dg-0096.params"
# INFO:root:Epoch[96] Train-accuracy=0.998177
# INFO:root:Epoch[96] Time cost=6.410
# INFO:root:Saved checkpoint to "dg-0097.params"
# INFO:root:Epoch[97] Train-accuracy=0.997830
# INFO:root:Epoch[97] Time cost=6.422
# INFO:root:Saved checkpoint to "dg-0098.params"
# INFO:root:Epoch[98] Train-accuracy=0.998090
# INFO:root:Epoch[98] Time cost=6.388
# INFO:root:Saved checkpoint to "dg-0099.params"
# INFO:root:Epoch[99] Train-accuracy=0.997917
# INFO:root:Epoch[99] Time cost=6.390
# INFO:root:Saved checkpoint to "dg-0100.params"

# %%
metric = mx.metric.create('loss')
for epoch in range(90):
    ylb_iter.reset()
    metric.reset()
    for batch in ylb_iter:
        mod.forward(batch, is_train=True)       # compute predictions
        
        mod.update_metric(metric, batch.label)  # accumulate prediction accuracy
        mod.backward()                          # compute gradients
        mod.update()                            # update parameters
    print('Epoch %d, Training %s' % (epoch, metric.get()))
# Out:
# Epoch 0, Training ('loss', 0.49999999735090467)
# Epoch 1, Training ('loss', 0.49999999933772615)
# Epoch 2, Training ('loss', 0.49999999867545236)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-cac9e21cbde2> in <module>()
#       3     ylb_iter.reset()
#       4     metric.reset()
# ----> 5     for batch in ylb_iter:
#       6         mod.forward(batch, is_train=True)       # compute predictions
#       7
#
# <ipython-input-7-3fde55438a39> in next(self)
#     122     def next(self):
#     123         if self.iter_next():
# --> 124             images, y = self.getdata()
#     125             return mx.io.DataBatch(data=[images], label=[y], pad=self.getpad(), index=None)
#     126         else:
#
# <ipython-input-7-3fde55438a39> in getdata(self)
#     111         sample_list = [self.idx[i] for i in l]
#     112         images, y = self.sample_batch(sample_list)
# --> 113         images = mx.nd.array(images)
#     114         y = mx.nd.array(y)
#     115         #kps = mx.nd.array(kps)
#
# /home/dingkou/dev/incubator-mxnet/python/mxnet/ndarray/utils.pyc in array(source_array, ctx, dtype, aux_types)
#     153         return _sparse_array(source_array, ctx=ctx, dtype=dtype, aux_types=aux_types)
#     154     else:
# --> 155         return _array(source_array, ctx=ctx, dtype=dtype)
#     156
#     157
#
# /home/dingkou/dev/incubator-mxnet/python/mxnet/ndarray/ndarray.pyc in array(source_array, ctx, dtype)
#    1581                 raise TypeError('source_array must be array like object')
#    1582     arr = empty(source_array.shape, ctx, dtype)
# -> 1583     arr[:] = source_array
#    1584     return arr
#    1585
#
# /home/dingkou/dev/incubator-mxnet/python/mxnet/ndarray/ndarray.pyc in __setitem__(self, key, value)
#     400                 _internal._set_value(float(value), out=self)
#     401             elif isinstance(value, (np.ndarray, np.generic)):
# --> 402                 self._sync_copyfrom(value)
#     403             else:
#     404                 raise TypeError(
#
# /home/dingkou/dev/incubator-mxnet/python/mxnet/ndarray/ndarray.pyc in _sync_copyfrom(self, source_array)
#     574             self.handle,
#     575             source_array.ctypes.data_as(ctypes.c_void_p),
# --> 576             ctypes.c_size_t(source_array.size)))
#     577
#     578     def _slice(self, start, stop):
#
# KeyboardInterrupt:

# %%
mod.save_checkpoint('ylb', 199)
